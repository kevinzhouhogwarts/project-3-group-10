# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# The path to our CSV file
health_data = Path("Resources/health_data_2023_cancer.csv")

# Read our data into pandas
health_data_df = pd.read_csv(health_data)
health_data_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc         DataSource   Topic  \
# 0       2008     2012           NY     New York  Death Certificate  Cancer
# 1       2009     2013           NY     New York  Death Certificate  Cancer
# 2       2011     2015           NY     New York  Death Certificate  Cancer
# 3       2012     2016           NY     New York  Death Certificate  Cancer
# 4       2012     2016           CO     Colorado  Death Certificate  Cancer
#
#                                            Question  Response DataValueUnit  \
# 0  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 1  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 2  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 3  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 4                 Cancer of the prostate, mortality       NaN           NaN
#
#            DataValueType  ...  LocationID  TopicID QuestionID DataValueTypeID  \
# 0  Average Annual Number  ...          36      CAN    CAN10_2      AVGANNNMBR
# 1  Average Annual Number  ...          36      CAN    CAN10_2      AVGANNNMBR
# 2  Average Annual Number  ...          36      CAN    CAN10_2      AVGANNNMBR
# 3  Average Annual Number  ...          36      CAN    CAN10_2      AVGANNNMBR
# 4  Average Annual Number  ...           8      CAN    CAN11_2      AVGANNNMBR
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                     GENDER               GENM                       NaN
# 1                     GENDER               GENM                       NaN
# 2                     GENDER               GENM                       NaN
# 3                     GENDER               GENM                       NaN
# 4                    OVERALL                OVR                       NaN
#
#   StratificationID2  StratificationCategoryID3  StratificationID3
# 0               NaN                        NaN                NaN
# 1               NaN                        NaN                NaN
# 2               NaN                        NaN                NaN
# 3               NaN                        NaN                NaN
# 4               NaN                        NaN                NaN
#
# [5 rows x 34 columns]

# %%
# Import necessary libraries
import pandas as pd

# Assuming health_data_df is already loaded from a CSV file

# Filter the data to exclude 'Invasive cancer (all sites combined), incidence' and only include 'Cancer' in the 'Topic' column
filtered_df = health_data_df[
    (health_data_df['Topic'] == 'Cancer') &
    (health_data_df['Question'] != 'Invasive cancer (all sites combined), incidence')
]

# Remove rows where 'LocationDesc' is 'United States'
filtered_df = filtered_df[filtered_df['LocationDesc'] != 'United States']

# Group by 'LocationDesc' and calculate the mean 'DataValue' to get the average number of people with cancer by state
cancer_by_state = filtered_df.groupby('LocationDesc')['DataValue'].mean().reset_index()

# Sort the result by 'DataValue' in descending order
cancer_by_state_sorted = cancer_by_state.sort_values(by='DataValue', ascending=False)

# Display the sorted result
print(cancer_by_state_sorted)
# Out:
#             LocationDesc    DataValue
# 4             California  1472.402085
# 9                Florida  1172.052736
# 14              Illinois  1132.117282
# 33              New York  1074.334654
# 45                 Texas  1014.383698
# 39          Pennsylvania   818.877380
# 36                  Ohio   736.313722
# 23              Michigan   573.383491
# 34        North Carolina   567.484553
# 31            New Jersey   524.539984
# 10               Georgia   511.772686
# 22         Massachusetts   448.326778
# 44             Tennessee   446.021373
# 49              Virginia   434.806575
# 15               Indiana   427.883168
# 26              Missouri   410.304419
# 18              Kentucky   373.586410
# 50            Washington   356.218321
# 52             Wisconsin   355.316451
# 0                Alabama   349.687479
# 42        South Carolina   333.351834
# 21              Maryland   332.162917
# 2                Arizona   323.649448
# 19             Louisiana   312.471290
# 24             Minnesota   303.887617
# 38                Oregon   253.443686
# 16                  Iowa   249.723418
# 25           Mississippi   249.127239
# 6            Connecticut   243.224652
# 5               Colorado   239.637822
# 37              Oklahoma   237.668830
# 3               Arkansas   232.882683
# 17                Kansas   226.824631
# 51         West Virginia   218.651110
# 20                 Maine   164.512686
# 29                Nevada   156.246136
# 30         New Hampshire   151.868549
# 28              Nebraska   140.461901
# 46                  Utah   130.487735
# 13                 Idaho   129.210524
# 32            New Mexico   127.451226
# 12                Hawaii   112.595428
# 27               Montana   112.501600
# 41          Rhode Island   109.836860
# 7               Delaware   104.011127
# 47               Vermont   103.061365
# 43          South Dakota    98.837507
# 35          North Dakota    89.711346
# 40           Puerto Rico    69.895556
# 53               Wyoming    69.827329
# 8   District of Columbia    67.741585
# 48        Virgin Islands    60.750000
# 11                  Guam    59.857857
# 1                 Alaska    58.723364

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Sort the DataFrame by 'DataValue' in descending order
cancer_by_state_sorted = cancer_by_state.sort_values(by='DataValue', ascending=False)

# Visualize the data using a bar plot
plt.figure(figsize=(12, 6))
plt.bar(cancer_by_state_sorted['LocationDesc'], cancer_by_state_sorted['DataValue'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Number of People with Cancer')
plt.title('Number of People with Cancer by State')
plt.xticks(rotation=90)
plt.show()

# %%
filtered_df = health_data_df[(health_data_df['DataSource'] == 'Statewide central cancer registries') &
                 (health_data_df['StratificationCategory1'] == 'Overall')]

# Group by the filtered DataFrame and calculate the mean of DataValue
mean_data_value = filtered_df.groupby(['DataSource', 'StratificationCategory1'])['DataValue'].mean().reset_index()
mean_data_value
# Out:
#                             DataSource StratificationCategory1   DataValue
# 0  Statewide central cancer registries                 Overall  105.785547

# %%
# Filter based on the specified conditions and exclude "Invasive cancer (all sites combined), incidence"
filtered_df = health_data_df[
    (health_data_df['DataSource'] == 'Statewide central cancer registries') &
    (health_data_df['Question'] != 'Invasive cancer (all sites combined), incidence')
]

# Group by the filtered DataFrame and calculate the mean of DataValue
state_mean_data_value = filtered_df.groupby(['Question'])['DataValue'].mean().reset_index()

# Sort by DataValue in descending order
state_mean_data_value_sorted = state_mean_data_value.sort_values(by='DataValue', ascending=False)

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(state_mean_data_value_sorted['Question'], state_mean_data_value_sorted['DataValue'], color='red')

# Adding labels and title
plt.xlabel('Avg Annual Per 100,000 People')
plt.ylabel('Specific Cancer Type')
plt.title('Cancer in US Population')

plt.tight_layout()  # Adjusts layout to fit labels and title properly
plt.show()

# %%
# Filter based on the specified conditions and exclude "Invasive cancer (all sites combined), incidence"
filtered_df = health_data_df[
    (health_data_df['DataSource'] == 'Death Certificate') &
    (health_data_df['Question'] != 'Invasive cancer (all sites combined), mortality')
]

# Group by the filtered DataFrame and calculate the mean of DataValue
state_mean_data_value = filtered_df.groupby(['Question'])['DataValue'].mean().reset_index()

# Sort by DataValue in descending order
state_mean_data_value_sorted = state_mean_data_value.sort_values(by='DataValue', ascending=False)

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(state_mean_data_value_sorted['Question'], state_mean_data_value_sorted['DataValue'], color='green')

# Adding labels and title
plt.xlabel('Avg Annual Per 100,000')
plt.ylabel('Specific Cancer Type')
plt.title('Cancer Deaths')

plt.tight_layout()  # Adjusts layout to fit labels and title properly
plt.show()

# %%
filtered_df = health_data_df[
    (health_data_df['DataSource'] == 'Statewide central cancer registries') &
    (health_data_df['Question'] != 'Invasive cancer (all sites combined), incidence') &
    (health_data_df['StratificationCategory1'] == 'Race/Ethnicity')
]

# Group by Stratification1 and calculate the mean of DataValue
grouped_df = filtered_df.groupby('Stratification1')['DataValue'].mean().reset_index()

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(grouped_df['Stratification1'], grouped_df['DataValue'], color='skyblue')

# Adding labels and title
plt.xlabel('Avg Annual Per 100,000 People')
plt.ylabel('Race/Ethnicity')
plt.title('Average Data Value by Race/Ethnicity')

# You can remove this line to let matplotlib position the label correctly
# plt.gca().get_xaxis().set_label_coords(1.05, 0.5)

plt.tight_layout()  # Adjusts layout to fit labels and title properly
plt.show()

# %%
filtered_df = health_data_df[
    (health_data_df['DataSource'] == 'Statewide central cancer registries') &
    (health_data_df['Question'] != 'Invasive cancer (all sites combined), incidence') &
    (health_data_df['StratificationCategory1'] == 'Gender')
]

# Group by Stratification1 and calculate the mean of DataValue
grouped_df = filtered_df.groupby('Stratification1')['DataValue'].mean().reset_index()

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(grouped_df['Stratification1'], grouped_df['DataValue'], color='purple')

# Adding labels and title
plt.xlabel('Avg Annual Per 100,000 People')
plt.ylabel('Gender')
plt.title('Average Data Value by Gender')

# You can remove this line to let matplotlib position the label correctly
# plt.gca().get_xaxis().set_label_coords(1.05, 0.5)

plt.tight_layout()  # Adjusts layout to fit labels and title properly
plt.show()

# %%
import plotly.express as px

# Dictionary to map state names to abbreviations
state_abbrev = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI',
    'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT',
    'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV',
    'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# Filter the DataFrame to exclude 'Invasive cancer (all sites combined), incidence'
filtered_df = health_data_df[health_data_df['Question'] != 'Invasive cancer (all sites combined), incidence']

# Map full state names to abbreviations in your DataFrame
filtered_df['StateAbbrev'] = filtered_df['LocationDesc'].map(state_abbrev)

# Create a choropleth map using the state abbreviations
fig = px.choropleth(filtered_df,
                    locations='StateAbbrev',  # Use the new column with state abbreviations
                    locationmode='USA-states',  # Match state abbreviations
                    color='DataValue',
                    color_range=[0,250],# Data to color code by
                    hover_name='LocationDesc',  # Info on hover
                    color_continuous_scale='Greens',  # Color scale
                    scope='usa',  # Limit map to USA
                    labels={'DataValue':'Cancer Population'}  # Label for color bar
                   )

# Add title
fig.update_layout(title_text='Cancer Population by State in the U.S.', geo_scope='usa')

# Show the figure
fig.show()
# Out:
# /var/folders/0b/g_byk81n7tqfg3pn6q677b380000gn/T/ipykernel_11662/1738926094.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 25
#      22 filtered_df['StateAbbrev'] = filtered_df['LocationDesc'].map(state_abbrev)
#      24 # Create a choropleth map using the state abbreviations
# ---> 25 fig = px.choropleth(filtered_df,
#      26                     locations='StateAbbrev',  # Use the new column with state abbreviations
#      27                     locationmode='USA-states',  # Match state abbreviations
#      28                     color='DataValue',
#      29                     color_range=[0,250],# Data to color code by
#      30                     hover_name='LocationDesc',  # Info on hover
#      31                     color_continuous_scale='Greens',  # Color scale
#      32                     scope='usa',  # Limit map to USA
#      33                     labels={'DataValue':'Cancer Population'}  # Label for color bar
#      34                    )
#      36 # Add title
#      37 fig.update_layout(title_text='Cancer Population by State in the U.S.', geo_scope='usa')
#
# TypeError: choropleth() got an unexpected keyword argument 'color_range'
