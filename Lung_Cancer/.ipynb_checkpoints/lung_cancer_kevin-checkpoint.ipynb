# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# print(os.getcwd()) Verify working location

# %%
path = Path("../Resources/lung_cancer_data.csv")
raw_df = pd.read_csv(path, low_memory=False)

# display(raw_df)

# %%
# Clean data and prepare for analysis

# List all column names
print(raw_df.columns)

# Drop unnecessary columns
dropped_df = raw_df.drop(['Topic', 'Response', 'DataValueAlt', 'DataValueFootnoteSymbol',
       'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory2',
       'Stratification2', 'StratificationCategory3', 'Stratification3', 'GeoLocation', 'ResponseID',
        'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
       'StratificationCategoryID2', 'StratificationID2', 'StratificationCategoryID3', 'StratificationID3'], axis=1)
display(dropped_df)

# Create DataFrame for Overall values per State/Territory

# Create DataFrame for Female values per State/Territory

# Create DataFrame for Male values per State/Territory
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')
#       YearStart  YearEnd LocationAbbr LocationDesc  \
# 0          2008     2012           AL      Alabama
# 1          2012     2016           AL      Alabama
# 2          2009     2013           AL      Alabama
# 3          2012     2016           AL      Alabama
# 4          2015     2019           AL      Alabama
# ...         ...      ...          ...          ...
# 6651       2015     2019           WY      Wyoming
# 6652       2009     2013           WY      Wyoming
# 6653       2009     2013           WY      Wyoming
# 6654       2012     2016           WY      Wyoming
# 6655       2014     2018           WY      Wyoming
#
#                                DataSource  \
# 0     Statewide central cancer registries
# 1     Statewide central cancer registries
# 2                       Death Certificate
# 3     Statewide central cancer registries
# 4     Statewide central cancer registries
# ...                                   ...
# 6651                    Death Certificate
# 6652                    Death Certificate
# 6653  Statewide central cancer registries
# 6654  Statewide central cancer registries
# 6655  Statewide central cancer registries
#
#                                         Question DataValueUnit  \
# 0     Cancer of the lung and bronchus, incidence   per 100,000
# 1     Cancer of the lung and bronchus, incidence   per 100,000
# 2     Cancer of the lung and bronchus, mortality   per 100,000
# 3     Cancer of the lung and bronchus, incidence   per 100,000
# 4     Cancer of the lung and bronchus, incidence   per 100,000
# ...                                          ...           ...
# 6651  Cancer of the lung and bronchus, mortality   per 100,000
# 6652  Cancer of the lung and bronchus, mortality   per 100,000
# 6653  Cancer of the lung and bronchus, incidence   per 100,000
# 6654  Cancer of the lung and bronchus, incidence   per 100,000
# 6655  Cancer of the lung and bronchus, incidence   per 100,000
#
#                          DataValueType  DataValue StratificationCategory1  \
# 0     Average Annual Age-adjusted Rate        0.2          Race/Ethnicity
# 1     Average Annual Age-adjusted Rate       54.4          Race/Ethnicity
# 2     Average Annual Age-adjusted Rate       14.5          Race/Ethnicity
# 3     Average Annual Age-adjusted Rate       21.1          Race/Ethnicity
# 4     Average Annual Age-adjusted Rate       50.8          Race/Ethnicity
# ...                                ...        ...                     ...
# 6651  Average Annual Age-adjusted Rate       30.4                 Overall
# 6652  Average Annual Age-adjusted Rate       39.1          Race/Ethnicity
# 6653  Average Annual Age-adjusted Rate       52.7                  Gender
# 6654  Average Annual Age-adjusted Rate        NaN          Race/Ethnicity
# 6655  Average Annual Age-adjusted Rate        0.7          Race/Ethnicity
#
#                        Stratification1
# 0            Asian or Pacific Islander
# 1                  White, non-Hispanic
# 2                             Hispanic
# 3                             Hispanic
# 4                  White, non-Hispanic
# ...                                ...
# 6651                           Overall
# 6652               White, non-Hispanic
# 6653                              Male
# 6654         Asian or Pacific Islander
# 6655  American Indian or Alaska Native
#
# [6656 rows x 11 columns]
