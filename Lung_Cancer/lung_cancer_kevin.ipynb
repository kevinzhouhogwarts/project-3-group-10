# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# print(os.getcwd()) Verify working location

# %%
path = Path("../Resources/lung_cancer_data.csv")
raw_df = pd.read_csv(path, low_memory=False)

# display(raw_df)

# %%
# Clean data and prepare for analysis

# List all column names
# print(raw_df.columns)

# Drop unnecessary columns
dropped_df = raw_df.drop(['Topic', 'Question', 'Response', 'DataValueAlt', 'DataValueFootnoteSymbol',
       'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory2',
       'Stratification2', 'StratificationCategory3', 'Stratification3', 'GeoLocation', 'ResponseID',
        'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
       'StratificationCategoryID2', 'StratificationID2', 'StratificationCategoryID3', 'StratificationID3'], axis=1)
# display(dropped_df)

# Create DataFrame for Overall values per State/Territory
overall_df = dropped_df.loc[dropped_df["StratificationCategory1"] == "Overall"].drop(["LocationDesc", "StratificationCategory1", "Stratification1"], axis=1)
overall_df = overall_df.loc[(overall_df["LocationAbbr"] == "CA") & (overall_df["DataSource"] == "Statewide central cancer registries")].sort_values(by="YearStart")
display(overall_df)

# Create DataFrame for Female values per State/Territory
overall_df = dropped_df.loc[dropped_df["StratificationCategory1"] == "Overall"].drop(["LocationDesc", "StratificationCategory1", "Stratification1"], axis=1)
overall_df = overall_df.loc[(overall_df["LocationAbbr"] == "CA") & (overall_df["DataSource"] == "Statewide central cancer registries")].sort_values(by="YearStart")
display(overall_df)

# Create DataFrame for Male values per State/Territory
# Out:
#      YearStart  YearEnd LocationAbbr                           DataSource  \
# 526       2008     2012           CA  Statewide central cancer registries
# 599       2009     2013           CA  Statewide central cancer registries
# 610       2010     2014           CA  Statewide central cancer registries
# 572       2011     2015           CA  Statewide central cancer registries
# 579       2012     2016           CA  Statewide central cancer registries
# 602       2013     2017           CA  Statewide central cancer registries
# 630       2014     2018           CA  Statewide central cancer registries
# 573       2015     2019           CA  Statewide central cancer registries
#
#     DataValueUnit                     DataValueType  DataValue
# 526   per 100,000  Average Annual Age-adjusted Rate       48.4
# 599   per 100,000  Average Annual Age-adjusted Rate       46.9
# 610   per 100,000  Average Annual Age-adjusted Rate       45.1
# 572   per 100,000  Average Annual Age-adjusted Rate       43.8
# 579   per 100,000  Average Annual Age-adjusted Rate       42.8
# 602   per 100,000  Average Annual Age-adjusted Rate       41.6
# 630   per 100,000  Average Annual Age-adjusted Rate       40.3
# 573   per 100,000  Average Annual Age-adjusted Rate       39.1
